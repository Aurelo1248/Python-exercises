# %%
import pandas as pd
from pandas import Series, DataFrame

pd.options.display.max_rows = 20

lf = pd.read_csv('Bibliografia.csv')
bonus = pd.read_csv('Dodatek.csv')

wszystko = pd.concat([lf, bonus], ignore_index=True)

wszystko.to_csv('Nowa bibliografia.csv', index=False)

wszystko = pd.read_csv('Nowa bibliografia.csv')
delet = wszystko[(wszystko.Author != 'Richard Dawkins') & (wszystko.Author != 'Joanne Rowling')]
delet.to_csv('Ocenzurowana.csv', index=False)
# Out:
#                       Title             Author  Published             Genre
# 0            Fahrenheit 451       Ray Bradbury       1953          Dystopic
# 2              Silmarillion       John Tolkien       1977           Fantasy
# 3          The Way of Kings  Brandon Sanderson       2010           Fantasy
# 4                  Twilight    Stephanie Meyer       2005           Fantasy
# 5                      Dune      Frank Herbert       1976   Science fiction
# 6   A Brief History of Time    Stephen Hawking       1960   Popular science
# 8     To Kill a Mockingbird         Harper Lee       1965     Bildungsroman
# 9                 The Stand       Stephen King       1978  Post-apocalyptic
# 11     The Lord of The Ring       John Tolkien       1955           Fantasy
# 12        Words of Radiance  Brandon Sanderson       2014           Fantasy
# 13   The Fault in Our Stars         John Green       2012       Young adult
# ...
